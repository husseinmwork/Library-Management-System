# %%
from services.library_service import LibraryService

# %%
service = LibraryService()

service.add_sample_data()

service.show_books()

user = service.register_user("Hussein")

service.borrow_book(user, "Python Basics")

service.show_books()
# Out:
# Books in My Library:
# - Python Basics - John Doe (ISBN: 111) [Available]
# - Advanced Python - Jane Doe (ISBN: 222) [Available]
# - OOP Design - Mark Smith (ISBN: 333) [Available]
# Hussein borrowed 'Python Basics'
#
# Books in My Library:
# - Python Basics - John Doe (ISBN: 111) [Borrowed]
# - Advanced Python - Jane Doe (ISBN: 222) [Available]
# - OOP Design - Mark Smith (ISBN: 333) [Available]
